# %% [markdown]
# ### Importing data and libraries

# %%
import numpy as np
import pandas as pd
import networkx as nx

# %%
mta_stations = pd.read_csv('data/MTA_Stations.csv')
mta_stations.head()
# Out:
#   GTFS Stop ID  Station ID  Complex ID Division     Line  \
# 0          R01           1           1      BMT  Astoria
# 1          R03           2           2      BMT  Astoria
# 2          R04           3           3      BMT  Astoria
# 3          R05           4           4      BMT  Astoria
# 4          R06           5           5      BMT  Astoria
#
#               Stop Name Borough    CBD Daytime Routes Structure  \
# 0  Astoria-Ditmars Blvd       Q  False            N W  Elevated
# 1          Astoria Blvd       Q  False            N W  Elevated
# 2                 30 Av       Q  False            N W  Elevated
# 3              Broadway       Q  False            N W  Elevated
# 4                 36 Av       Q  False            N W  Elevated
#
#    GTFS Latitude  GTFS Longitude North Direction Label South Direction Label  \
# 0      40.775036      -73.912034             Last Stop             Manhattan
# 1      40.770258      -73.917843               Astoria             Manhattan
# 2      40.766779      -73.921479               Astoria             Manhattan
# 3      40.761820      -73.925508               Astoria             Manhattan
# 4      40.756804      -73.929575               Astoria             Manhattan
#
#    ADA  ADA Northbound  ADA Southbound ADA Notes                  Georeference
# 0    0               0               0       NaN  POINT (-73.912034 40.775036)
# 1    1               1               1       NaN  POINT (-73.917843 40.770258)
# 2    0               0               0       NaN  POINT (-73.921479 40.766779)
# 3    0               0               0       NaN   POINT (-73.925508 40.76182)
# 4    0               0               0       NaN  POINT (-73.929575 40.756804)

# %%
mta_rides = pd.read_csv('data/MTA_Passengers.csv')
mta_rides.head()
# Out:
#    Year  Month Day of Week  Hour of Day               Timestamp  \
# 0  2024      1      Monday            1  01/08/2024 01:00:00 AM
# 1  2024      1      Monday            1  01/08/2024 01:00:00 AM
# 2  2024      1      Monday            1  01/08/2024 01:00:00 AM
# 3  2024      1      Monday            1  01/08/2024 01:00:00 AM
# 4  2024      1      Monday            1  01/08/2024 01:00:00 AM
#
#    Origin Station Complex ID Origin Station Complex Name  Origin Latitude  \
# 0                         26           DeKalb Av (B,Q,R)        40.690635
# 1                        231              Grand St (B,D)        40.718267
# 2                        313               72 St (1,2,3)        40.778453
# 3                        320                   23 St (1)        40.744081
# 4                        399    68 St-Hunter College (6)        40.768141
#
#    Origin Longitude  Destination Station Complex ID  \
# 0        -73.981824                             355
# 1        -73.993753                             284
# 2        -73.981970                              71
# 3        -73.995657                             309
# 4        -73.963870                             618
#
#   Destination Station Complex Name  Destination Latitude  \
# 0                Winthrop St (2,5)             40.656652
# 1                    Nassau Av (G)             40.724635
# 2                         8 Av (N)             40.635064
# 3                       103 St (1)             40.799446
# 4           14 St (A,C,E)/8 Av (L)             40.740335
#
#    Destination Longitude  Estimated Average Ridership  \
# 0             -73.950200                       0.5556
# 1             -73.951277                       0.3068
# 2             -74.011719                       0.3012
# 3             -73.968379                       0.9000
# 4             -74.002134                       0.2940
#
#                    Origin Point             Destination Point
# 0  POINT (-73.981824 40.690635)    POINT (-73.9502 40.656652)
# 1  POINT (-73.993753 40.718267)  POINT (-73.951277 40.724635)
# 2   POINT (-73.98197 40.778453)  POINT (-74.011719 40.635064)
# 3  POINT (-73.995657 40.744081)  POINT (-73.968379 40.799446)
# 4   POINT (-73.96387 40.768141)  POINT (-74.002134 40.740335)

# %%
G = nx.Graph()

# %% [markdown]
# ### Prompt

# %% [markdown]
# How should you approach solving this problem?
#
# To create a graph-based representation of the data, you may start considering the
# following:
# 1. Nodes: MTA Subway Stations
# 2. Edges: Source and destination pairs of Ridership
# 3. Edge types: Directed? weighted? Self-loops?
# 4. Node attributes: What are the relevant information from the MTA Subway Stations
# dataset, which will help you do the analysis: Station type, CBD status, and ADA
# accessibility status, Train routes, GPS locations, Borough information?
# 5. Edge attributes: What are the relevant information from the MTA Subway Origin-
# Destination Ridership Estimate dataset will be of help? Passenger volume, day of the
# week, and hour of day?
#
# Once you’re able to represent this data, as part of graph-based representation, you are
# expected to develop queries on the graph-based representation which should return the
# following:
# 1) What are the top 5 origin sub-way stations from where most riders took subway ride:
#     1. a. Across each borough (Manhattan, Brooklyn, Queens, Bronx, State Island)
#     2. b. On Monday, Tuesday, Wednesday (combined)
#     3. c. On Saturday and Sunday (combined)
#     4. d. Between 1am-5am across all days and boroughs
#     5. e. Between 6am-9am across all days and boroughs
# 2) What are the top 5 destination sub-way stations from where most riders took subway ride:
#     1. a. Across each borough (Manhattan, Brooklyn, Queens, Bronx, State Island)
#     2. b. On Thursday and Friday (combined)
#     3. c. On Saturday only
#     4. d. Between 12am-5am across all days and boroughs
#     5. e. Between 6pm-9pm across all days and boroughs
# 3) What are the top 10 congested source-destination sub-way stations pair on:
#     1. Monday between 1pm-2pm?
#     2. On Queens borough, on Fridays between 6pm-9pm?
#     3. On Brooklyn borough, Ridership between 1am-5am?
#     4. Source is Brooklyn, Destination is Manhattan, Monday-Thursday 6am-7am?
#     5. Source is Bronx, Destination is Manhattan, Monday-Thursday 6am-7am?
#     6. Source is Staten Island, Destination is Manhattan, Monday-Thursday 6am-7am?
